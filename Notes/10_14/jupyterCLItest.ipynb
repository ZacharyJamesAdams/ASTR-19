# %% [markdown]
# # testing
# ## hullo
# > jslkdfjsdf
# >> sldfkjslfkj

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = np.linspace(0,100.,101)
x = (np.pi/25) * n
y = np.sin(x)

# %%
fig,ax = plt.subplots()
p = ax.plot(x,y)
